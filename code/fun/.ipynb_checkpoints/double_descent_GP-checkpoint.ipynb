# %%
using Distributions, StatsBase,PyPlot
using LinearAlgebra
PyPlot.svg(true)
# Out:
# true

# %%
a = [rand(Normal(0,1/s^0.4)) for s in 1:50]
L = length(a)
phi(x,k) = x^k
f(x) = sum([phi(x,k)*a[k] for k in 1:L])

x = collect(-1:0.1:1);
M = length(x)
y = f.(x) + rand(Normal(0,0.1),M)


plt.plot(x,f.(x))

plt.plot(x,y,"o")
length(x)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 21

# %%
xp = collect(-1:0.003:1)
Koo = hcat([[k.(xi,xj) for xi in x] for xj in x]...)
Kpo = hcat([[k.(xi,xj) for xi in xp] for xj in x]...)
K = Koo .+ 0.01*Matrix(I, length(x),length(x))
plt.plot(xp,Kpo*inv(K)*y)
plt.plot(x,f.(x))
plt.plot(x,y,"o")
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x1e8005dc0>

# %%
E = []
z_range = collect(10:1:100)
for z in z_range
    function s(k)
        if k>z
            return 0
        else 
            return 1
        end
        return 4/z^k*z
    end
    
    function k(x1,x2)
#         sm = 0
#         for k in collect(1:100)
#             sm = sm + s(k)*(x1*x2)^k
#         end
        return exp(-abs(x1-x2)/z)
    end
    

    xp = collect(-1:0.3:1)
    Koo = hcat([[k.(xi,xj) for xi in x] for xj in x]...)
    Kpo = hcat([[k.(xi,xj) for xi in xp] for xj in x]...)
    K = Koo .+ 0.4*Matrix(I, length(x),length(x))
    push!(E,sum((f.(xp) .- Kpo*inv(K)*y).^2))
end

# %%
plt.loglog(z_range,E)

# %%
hcat([[k.(xj,xi) for xi in xp] for xj in xp]
# Out:
# 201×201 Matrix{Float64}:
#  12.0      11.7616   11.5264   11.2943   …  -3.84317  -3.9208   -4.0
#  11.7616   11.5287   11.2989   11.0722      -3.7686   -3.84394  -3.9208
#  11.5264   11.2989   11.0744   10.853       -3.6955   -3.7686   -3.84317
#  11.2943   11.0722   10.853    10.6367      -3.62384  -3.69476  -3.76709
#  11.0653   10.8485   10.6344   10.4232      -3.55361  -3.62239  -3.69254
#  10.8395   10.6278   10.4189   10.2127   …  -3.48477  -3.55148  -3.6195
#  10.6167   10.4101   10.2062   10.0049      -3.41732  -3.48199  -3.54794
#  10.397    10.1954    9.99642   9.8         -3.35122  -3.41391  -3.47783
#  10.1804    9.98367   9.78951   9.59786     -3.28645  -3.34721  -3.40915
#   9.96668   9.77484   9.58545   9.39849     -3.22299  -3.28187  -3.34188
#   9.756     9.56892   9.38421   9.20187  …  -3.16082  -3.21787  -3.276
#   9.54828   9.36587   9.18578   9.00797     -3.09991  -3.15517  -3.21148
#   9.34349   9.16568   8.99012   8.81678     -3.04025  -3.09377  -3.14829
#   ⋮                                      ⋱                       ⋮
#  -3.21148  -3.15517  -3.09991  -3.04568      9.18578   9.36587   9.54828
#  -3.276    -3.21787  -3.16082  -3.10484  …   9.38421   9.56892   9.756
#  -3.34188  -3.28187  -3.22299  -3.16522      9.58545   9.77484   9.96668
#  -3.40915  -3.34721  -3.28645  -3.22684      9.78951   9.98367  10.1804
#  -3.47783  -3.41391  -3.35122  -3.28972      9.99642  10.1954   10.397
#  -3.54794  -3.48199  -3.41732  -3.35389     10.2062   10.4101   10.6167
#  -3.6195   -3.55148  -3.48477  -3.41936  …  10.4189   10.6278   10.8395
#  -3.69254  -3.62239  -3.55361  -3.48616     10.6344   10.8485   11.0653
#  -3.76709  -3.69476  -3.62384  -3.55432     10.853    11.0722   11.2943
#  -3.84317  -3.7686   -3.6955   -3.62384     11.0744   11.2989   11.5264
#  -3.9208   -3.84394  -3.7686   -3.69476     11.2989   11.5287   11.7616
#  -4.0      -3.9208   -3.84317  -3.76709  …  11.5264   11.7616   12.0

# %%
E = []
z_range = collect(10:1:100)
for z in z_range
    function s(k)
#         if k>z
#             return 0
#         else 
#             return 1
#         end
        return 4/z^k*z
    end
    
    function k(x1,x2)
        sm = 0
        for k in collect(1:100)
            sm = sm + s(k)*(x1*x2)^k
        end
        return sm
    end
    

    xp = collect(-1:0.3:1)
    Koo = hcat([[k.(xi,xj) for xi in x] for xj in x]...)
    Kpo = hcat([[k.(xi,xj) for xi in xp] for xj in x]...)
    K = Koo .+ 0.4*Matrix(I, length(x),length(x))
    push!(E,sum((f.(xp) .- Kpo*inv(K)*y).^2))
end

# %%
plt.loglog(z_range,E)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# 1-element Vector{PyCall.PyObject}:
#  PyObject <matplotlib.lines.Line2D object at 0x1e31e8b80>
